# %%
# This will pre-create any resources or elements for the training that are pre-requisites

# %% [markdown]
# Genie Space?

# %% [markdown]
# Agent tools from Lab 2 in case a user doesn't get them done?
